# %%
1
# Out:
# 1

# %%
### Package Import
import sys
import os
base_dir = os.environ['GEMS_HOME']
project_path = os.path.join(base_dir, 'python-refactor')
sys.path.insert(0, project_path)
from Code.utils import matlab

import scipy.io as sio
from scipy.io import netcdf
import numpy as np
import glob
import time
import h5py 
import pygrib

### Setting path
data_base_dir = os.path.join('/', 'media', 'sf_GEMS', 'Data')
emis_path = os.path.join(data_base_dir, 'Raw', 'EMIS')  
write_path = os.path.join(data_base_dir, 'Preprocessed_raw', 'EMIS')  
# emis_path = '/lustre/gpu_storage/Data/Aerosol/00_raw_data/EMIS/';
#path_data = '/share/irisnas5/Data/';
#path = [path_data,'pre/EMIS/'];


# emiss_header = ['ISOPRENE','TRP1','MEOH','ACET','CH4','NO',
#     'NO2','NH3','CCHO','HCOOH','HCHO','CCO_OH','BALD','MEK','RCO_OH',
#     'CO','ETHENE','ALK1','ALK2','ALK3','ALK4','ALK5','ARO1','ARO2',
#     'OLE1','OLE2','RCHO','NONR','CRES','GLY','IPROD','MACR','MGLY',
#     'NR','PHEN','PROD2','SO2','SULF','PM10','PEC','PM2_5','PMFINE',
#     'PNO3','POA','PSO4','PMC','ISOP'];

## 9 km domain
nr=82; nc=67;
YEARS = [2016] # range(2017, 2019+1)
KNU_dir = 'KNU_27_01'

for yr in YEARS:
    if (yr%4)==0: days=366
    else: days=365

    curr_path = os.path.join(emis_path, KNU_dir, str(yr))
    list_date = list(range(matlab.datenum(f'{yr}0101'), matlab.datenum(f'{yr}1231')+1))
    list_date = [str(d) for d in list_date]    
    list_char = [f'NIER_09h_EMIS_{d}' for d in list_date]
    list_char = [os.path.basename(f) for f in list_char]

    for doy in range(1, days+1):
        fname = f'egts3d_l.{yr}.{list_date[doy][4:8]}.{KNU_dir}.AQFv1.ncf'
        try:
            ncfile = netcdf.NetCDFFile(os.path.join(curr_path, list_char[doy-1], fname), 'r')
            var = list(ncfile.variables.keys())
            emiss_all = np.full((nr, nc, len(var)-1, 24), np.nan)  # From 01UTC to 00UTC (next day)
            
            for j in range(2, len(var)+1):
                temp = ncfile.variables[var[j]]
                data = temp[:]
                data = np.rot90(data)
                ncfile.close()
                emiss_all[:,:,j-2,2:]=np.float64(np.squeeze(data[:,:,0,:])) # vertical layer : 1
                    
                
                if doy != 1:
                    try:
                        ncfile = netcdf.NetCDFFile(os.path.join(curr_path, list_char[doy-2], fname), 'r')
                        temp = ncfile.variables[var[j]]
                        data2 = temp[:]
                        data2 = np.rot90(data2)
                        ncfile.close()
                        emiss_all[:,:,j-2,:2]=np.float64(np.squeeze(data2[:,:,0,1:3])) # forecast 01-02UTC
                    except:
                        pass
                    
            for utc in range(1, 24+1):
                emiss = emiss_all[:,:,:,utc]
                if utc==24:
                    if doy==days:
                        fname = f'emiss_9km_{yr+1}_001_00.mat'
                        matlab.savemat(os.path.join(write_path, KNU_dir, str(yr+1)), fname, {'emiss':emiss})
                    else:
                        fname = f'emiss_9km_{yr}_{doy+1:03d}_00.mat'
                        matlab.savemat(os.path.join(write_path, KNU_dir, str(yr)), fname, {'emiss':emiss})
                else:
                    fname = f'emiss_9km_{yr}_{doy:03d}_{utc:02d}.mat'
                    matlab.savemat(os.path.join(write_path, KNU_dir, str(yr)), fname, {'emiss':emiss})
            print (f'{yr}_{doy:03d}')
        except:
            print (f'{yr}_{doy:03d}_no_data!!!!')
            pass
        print (doy)
    print (yr)
# Out:
# 2016_001_no_data!!!!
# 1
# 2016_002_no_data!!!!
# 2
# 2016_003_no_data!!!!
# 3
# 2016_004_no_data!!!!
# 4
# 2016_005_no_data!!!!
# 5
# 2016_006_no_data!!!!
# 6
# 2016_007_no_data!!!!
# 7
# 2016_008_no_data!!!!
# 8
# 2016_009_no_data!!!!
# 9
# 2016_010_no_data!!!!
# 10
# 2016_011_no_data!!!!
# 11
# 2016_012_no_data!!!!
# 12
# 2016_013_no_data!!!!
# 13
# 2016_014_no_data!!!!
# 14
# 2016_015_no_data!!!!
# 15
# 2016_016_no_data!!!!
# 16
# 2016_017_no_data!!!!
# 17
# 2016_018_no_data!!!!
# 18
# 2016_019_no_data!!!!
# 19
# 2016_020_no_data!!!!
# 20
# 2016_021_no_data!!!!
# 21
# 2016_022_no_data!!!!
# 22
# 2016_023_no_data!!!!
# 23
# 2016_024_no_data!!!!
# 24
# 2016_025_no_data!!!!
# 25
# 2016_026_no_data!!!!
# 26
# 2016_027_no_data!!!!
# 27
# 2016_028_no_data!!!!
# 28
# 2016_029_no_data!!!!
# 29
# 2016_030_no_data!!!!
# 30
# 2016_031_no_data!!!!
# 31
# 2016_032_no_data!!!!
# 32
# 2016_033_no_data!!!!
# 33
# 2016_034_no_data!!!!
# 34
# 2016_035_no_data!!!!
# 35
# 2016_036_no_data!!!!
# 36
# 2016_037_no_data!!!!
# 37
# 2016_038_no_data!!!!
# 38
# 2016_039_no_data!!!!
# 39
# 2016_040_no_data!!!!
# 40
# 2016_041_no_data!!!!
# 41
# 2016_042_no_data!!!!
# 42
# 2016_043_no_data!!!!
# 43
# 2016_044_no_data!!!!
# 44
# 2016_045_no_data!!!!
# 45
# 2016_046_no_data!!!!
# 46
# 2016_047_no_data!!!!
# 47
# 2016_048_no_data!!!!
# 48
# 2016_049_no_data!!!!
# 49
# 2016_050_no_data!!!!
# 50
# 2016_051_no_data!!!!
# 51
# 2016_052_no_data!!!!
# 52
# 2016_053_no_data!!!!
# 53
# 2016_054_no_data!!!!
# 54
# 2016_055_no_data!!!!
# 55
# 2016_056_no_data!!!!
# 56
# 2016_057_no_data!!!!
# 57
# 2016_058_no_data!!!!
# 58
# 2016_059_no_data!!!!
# 59
# 2016_060_no_data!!!!
# 60
# 2016_061_no_data!!!!
# 61
# 2016_062_no_data!!!!
# 62
# 2016_063_no_data!!!!
# 63
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-f76e9d419cce> in <module>
#      47
#      48     for doy in range(1, days+1):
# ---> 49         fname = f'egts3d_l.{yr}.{list_date[doy][4:8]}.{KNU_dir}.AQFv1.ncf'
#      50         try:
#      51             ncfile = netcdf.NetCDFFile(os.path.join(curr_path, list_char[doy-1], fname), 'r')
#
# IndexError: list index out of range

# %%
curr_path
# Out:
# '/media/sf_GEMS/Data/Raw/EMIS/KNU_27_01/2016'

# %%
list_char = glob.glob(os.path.join(curr_path, '*.ncf'))
list_char = [os.path.basename(f) for f in list_char]

# %%
list_char[0]
# Out:
# 'egts3d_l.2016.0101.KNU_27_01.AQFv1.ncf'

# %%
j =2

# %%
ncfile = netcdf.NetCDFFile(os.path.join(curr_path, list_char[0]), 'r')
var = list(ncfile.variables.keys())

# %%
temp = ncfile.variables[var[j]]
data = temp[:].copy()
data = np.rot90(data)
ncfile.close()
# Out:
# /home/sehyun/GEMS_python/venv/lib/python3.6/site-packages/scipy/io/netcdf.py:317: RuntimeWarning: Cannot close a netcdf_file opened with mmap=True, when netcdf_variables or arrays referring to its data still exist. All data arrays obtained from such files refer directly to data on disk, and must be copied before the file can be cleanly closed. (See netcdf_file docstring for more information on mmap.)
#   ), category=RuntimeWarning)

# %%
data
# Out:
# array([[[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         ...,
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]],
#
#
#        [[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         ...,
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]],
#
#
#        [[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         ...,
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]],
#
#
#        ...,
#
#
#        [[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         ...,
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]],
#
#
#        [[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         ...,
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]],
#
#
#        [[[1.76599428e-01, 1.46049395e-01, 1.83540449e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.47866756e-01, 1.60354078e-01, 2.09091961e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.45301133e-01, 1.63412586e-01, 2.14165866e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [1.23601494e-04, 5.40849805e-06, 5.30109855e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.64907542e-04, 7.97688917e-05, 5.17220087e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [2.46059266e-04, 2.50202167e-04, 4.96256371e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[1.97543040e-01, 1.48922786e-01, 2.00986609e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.68293580e-01, 1.67016193e-01, 2.28227332e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.65961906e-01, 1.83325723e-01, 2.35420480e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [1.62529919e-04, 5.55176985e-06, 5.44152499e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [2.09196369e-04, 1.07849373e-04, 5.30921261e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [3.01176275e-04, 3.24823166e-04, 5.09402253e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[2.13669613e-01, 1.54366687e-01, 2.00662151e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.83986053e-01, 1.79307759e-01, 2.40849495e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.81994751e-01, 1.84784785e-01, 2.46556416e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [1.84489167e-04, 5.65026903e-06, 5.53806831e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [2.39241839e-04, 1.18154581e-04, 5.40340852e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [3.35256162e-04, 3.65891290e-04, 5.18440038e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         ...,
#
#         [[7.69839585e-02, 7.39096478e-02, 8.34826380e-02, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [5.99091053e-02, 7.60883614e-02, 1.03291906e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [6.83433563e-02, 8.14790949e-02, 1.14329956e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [7.14293419e-05, 2.78483913e-06, 2.72953889e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.15249830e-04, 4.32604102e-05, 2.66316943e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.45997561e-04, 1.59243864e-04, 2.55522718e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[7.62142763e-02, 7.42200688e-02, 8.21453631e-02, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [5.94638027e-02, 7.65511245e-02, 1.02518909e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [6.81252331e-02, 8.42033699e-02, 1.15260243e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [7.20962344e-05, 3.47433320e-06, 3.40534143e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.17877411e-04, 4.37108647e-05, 3.32253944e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.65504243e-04, 1.59645031e-04, 3.18787193e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[1.00325428e-01, 7.67389536e-02, 8.49229097e-02, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [7.87677467e-02, 7.90316910e-02, 1.04681201e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [8.79377797e-02, 8.73442367e-02, 1.16943702e-01, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [7.20676617e-05, 4.18173613e-06, 4.09869699e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.19711476e-04, 4.47333296e-05, 3.99903593e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.74262430e-04, 1.60690077e-04, 3.83694896e-06, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]]],
#       dtype=float32)

# %%
yr =2016

# %%
    list_date = list(range(matlab.datenum(f'{yr}0101'), matlab.datenum(f'{yr}1231')+1))

# %%
    list_date = [str(d) for d in list_date]

# %%
    list_char = [f'NIER_09h_EMIS_{d}' for d in list_date]

# %%
path_gpu = '/lustre/gpu_storage/Data/Aerosol/00_raw_data/EMIS/';
path_data = '/share/irisnas5/Data/';
path = [path_data,'pre/EMIS/'];

tic
% emiss_header = {'ISOPRENE','TRP1','MEOH','ACET','CH4','NO',...
%     'NO2','NH3','CCHO','HCOOH','HCHO','CCO_OH','BALD','MEK','RCO_OH',...
%     'CO','ETHENE','ALK1','ALK2','ALK3','ALK4','ALK5','ARO1','ARO2',...
%     'OLE1','OLE2','RCHO','NONR','CRES','GLY','IPROD','MACR','MGLY',...
%     'NR','PHEN','PROD2','SO2','SULF','PM10','PEC','PM2_5','PMFINE',...
%     'PNO3','POA','PSO4','PMC','ISOP'};
%% 9 km domain
nr=82; nc=67;
for yr=2017:2019
    if mod(yr,4)==0
        days=366;
    else
        days=365;
    end

cd([path_gpu,'KNU_09_01/',num2str(yr)])
list = repmat('NIER_09h_EMIS_',[days,1]);
list_date = [datenum([num2str(yr),'0101'],'yyyymmdd'):datenum([num2str(yr),'1231'],'yyyymmdd')]';
list_date = datestr(list_date,'yyyymmdd');
list = [list,list_date];

for doy=1:days
    fname = ['/egts3d_l.',num2str(yr),'.',list_date(doy,5:8),'.KNU_09_01.AQFv1.ncf'];
    try
        data_info = ncinfo([list(doy,:),fname]);
        var = {data_info.Variables.Name}';
        
        emiss_all = nan(nr,nc,length(var)-1,24); % From 01UTC to 00UTC (next day)
        for j=2:length(var)           
            eval(sprintf(['data=rot90(ncread([list(doy,:),fname], \''',var{j},'\''));']));
            emiss_all(:,:,j-1,3:end)=double(squeeze(data(:,:,1,:))); % vertical layer : 1
            
            if doy~=1
                try
                    eval(sprintf(['data2=rot90(ncread([list(doy-1,:),fname], \''',var{j},'\''));']));
                    emiss_all(:,:,j-1,1:2)=double(squeeze(data2(:,:,1,2:3))); % forecast 01-02UTC
                catch
                end
            end
        end
        
        for utc = 1:24
            emiss = emiss_all(:,:,:,utc);
            if utc==24
                if doy==days
                    save([path,'KNU_09_01/',num2str(yr+1),'/emiss_9km_',num2str(yr+1),...
                        '_001_00.mat'],'emiss')
                else
                    save([path,'KNU_09_01/',num2str(yr),'/emiss_9km_',num2str(yr),...
                        '_',num2str(doy+1,'%03i'),'_00.mat'],'emiss')
                end
            else
                save([path,'KNU_09_01/',num2str(yr),'/emiss_9km_',num2str(yr),...
                    '_',num2str(doy,'%03i'),'_',num2str(utc,'%02i'),'.mat'],'emiss')
            end
        end
        disp([num2str(yr),'_',num2str(doy,'%03i')])
    catch
        disp([num2str(yr),'_',num2str(doy,'%03i'),'_no_data!!!!'])
    end
end

toc

disp(num2str(yr))
end

toc


%% 27 km domain
nr=128; nc=174;
for yr=2017:2019
    tStart=tic;
    if mod(yr,4)==0; days=366; else; days=365; end
    
cd([path_gpu,'KNU_27_01/',num2str(yr)])
list = repmat('NIER_09h_EMIS_',[days,1]);
list_date = [datenum([num2str(yr),'0101'],'yyyymmdd'):datenum([num2str(yr),'1231'],'yyyymmdd')]';
list_date = datestr(list_date,'yyyymmdd');
list = [list,list_date];

for doy=1:days
    fname = ['/egts3d_l.',num2str(yr),'.',list_date(doy,5:8),'.KNU_27_01.AQFv1.ncf'];
    
    try
        data_info = ncinfo([list(doy,:),fname]);
        var = {data_info.Variables.Name}';
        
        emiss_all = nan(nr,nc,length(var)-1,24); % From 01UTC to 00UTC (next day)
        for j=2:length(var)
            eval(sprintf(['data=rot90(ncread([list(doy,:),fname], \''',var{j},'\''));']));
            emiss_all(:,:,j-1,3:end)=double(squeeze(data(:,:,1,:))); % vertical layer : 1
            
            if doy~=1
                try
                    eval(sprintf(['data2=rot90(ncread([list(doy-1,:),fname], \''',var{j},'\''));']));
                    emiss_all(:,:,j-1,1:2)=double(squeeze(data2(:,:,1,2:3))); % forecast 01-02UTC
                catch
                end
            end
        end
        
        for utc = 1:24
            emiss = emiss_all(:,:,:,utc);
            if utc==24
                if doy==days
                    save([path,'KNU_27_01/',num2str(yr+1),'/emiss_27km_',num2str(yr+1),...
                        '_001_00.mat'],'emiss')
                else
                    save([path,'KNU_27_01/',num2str(yr),'/emiss_27km_',num2str(yr),...
                        '_',num2str(doy+1,'%03i'),'_00.mat'],'emiss')
                end
            else
                save([path,'KNU_27_01/',num2str(yr),'/emiss_27km_',num2str(yr),...
                    '_',num2str(doy,'%03i'),'_',num2str(utc,'%02i'),'.mat'],'emiss')
            end
        end
        disp([num2str(yr),'_',num2str(doy,'%03i')])
    catch
        disp([num2str(yr),'_',num2str(doy,'%03i'),'_no_data!!!!'])
    end
end
disp(num2str(yr))

tElapsed = toc(tStart);
disp([num2str(tElapsed),' sec'])

end % yr

toc

%% yyyy_001_01, yyyy_001_02 Ž©¶ôµÈ°Å žžµé±â
% yr=2019;
% fname = [path_gpu,'KNU_27_01/',num2str(yr-1),...
%     '/NIER_09h_EMIS_',num2str(yr-1),'1231/egts3d_l.',num2str(yr),'.0101.KNU_27_01.AQFv1.ncf'];
% data_info = ncinfo(fname);
% var = {data_info.Variables.Name}';
% emiss_all = nan(nr,nc,length(var)-1,2);
% for j=2:length(var)
%     eval(sprintf(['data=rot90(ncread(fname, \''',var{j},'\''));']));
%     emiss_all(:,:,j-1,:)=double(squeeze(data(:,:,1,2:3))); % vertical layer : 1
% end
% 
% for utc = 1:2
%     emiss = emiss_all(:,:,:,utc);
%     save([path,'KNU_27_01/',num2str(yr),'/emiss_27km_',num2str(yr),...
%         '_001_',num2str(utc,'%02i'),'.mat'],'emiss')
% end
